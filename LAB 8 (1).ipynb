# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_iris
import pandas as pd
from scipy.spatial.distance import cdist

def inner_product_distance(x, y):
  """Calculates the distance between two points using inner product space.

  Args:
    x: A numpy array representing the first point.
    y: A numpy array representing the second point.

  Returns:
    The distance between the two points.
  """

  return np.sqrt(1 - np.dot(x, y) / (np.linalg.norm(x) * np.linalg.norm(y)))

# Load the Iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Calculate the distance between all pairs of points using inner product space
dist = cdist(df, df, metric=inner_product_distance)

# Display the distances
print(dist)
# Out:
# <ipython-input-34-df18ba8247f3>:16: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(1 - np.dot(x, y) / (np.linalg.norm(x) * np.linalg.norm(y)))
# [[0.00000000e+00 3.76939849e-02 3.55706586e-03 ... 3.28958347e-01
#   3.40720857e-01 3.36596561e-01]
#  [3.76939849e-02 0.00000000e+00 3.47641665e-02 ... 3.09595778e-01
#   3.25883299e-01 3.19570887e-01]
#  [3.55706586e-03 3.47641665e-02 0.00000000e+00 ... 3.26146174e-01
#   3.38128622e-01 3.33976917e-01]
#  ...
#  [3.28958347e-01 3.09595778e-01 3.26146174e-01 ...            nan
#   4.68537190e-02 2.95662062e-02]
#  [3.40720857e-01 3.25883299e-01 3.38128622e-01 ... 4.68537190e-02
#   1.49011612e-08 3.36266523e-02]
#  [3.36596561e-01 3.19570887e-01 3.33976917e-01 ... 2.95662062e-02
#   3.36266523e-02 0.00000000e+00]]

# %% [markdown]
# 1. Use the following distance metric

# %% [markdown]
# Euclidean distance

# %%
from sklearn.datasets import load_iris
import pandas as pd
from scipy.spatial.distance import cdist

df=pd.read_csv('/content/iris.csv')

# Calculate the distance between all pairs of points
dist = cdist(df, df, metric='euclidean')

# Display the distances
print(dist)
# Out:
# [[0.         0.53851648 0.5        ... 1.25299641 1.         0.92195445]
#  [0.53851648 0.         0.28284271 ... 1.30384048 0.53851648 0.82462113]
#  [0.5        0.28284271 0.         ... 1.52970585 0.80622577 1.07703296]
#  ...
#  [1.25299641 1.30384048 1.52970585 ... 0.         1.17046999 0.50990195]
#  [1.         0.53851648 0.80622577 ... 1.17046999 0.         0.67082039]
#  [0.92195445 0.82462113 1.07703296 ... 0.50990195 0.67082039 0.        ]]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
# Perform hierarchical clustering using Diana

X= df

Z = linkage(dist, 'ward')

# Obtain cluster labels for a specific distance threshold
distance_threshold = 3
labels = fcluster(Z, distance_threshold, criterion='distance')

# Add the cluster labels to the DataFrame
df['cluster'] = labels

# Print the DataFrame with cluster labels
print(df)

# Plot the dendrogram (optional)
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
dendrogram(Z,orientation='bottom')
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
#     sepal_length  sepal_width  cluster
# 0            5.1          3.5       15
# 1            4.9          3.0       13
# 2            4.7          3.2       12
# 3            4.6          3.1       12
# 4            5.0          3.6       14
# ..           ...          ...      ...
# 95           5.7          3.0       22
# 96           5.7          2.9       22
# 97           6.2          2.9       20
# 98           5.1          2.5        9
# 99           5.7          2.8       23
#
# [100 rows x 3 columns]
# <ipython-input-36-a4eefb9d1770>:6: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'ward')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'single')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - single)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-37-13a65d523682>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'single')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'complete')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - complete)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-38-b04236d03060>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'complete')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'ward')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - ward)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-39-a1745fbe19a2>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'ward')

# %% [markdown]
# Manhattan distance

# %%
# Calculate the Manhattan distance between all pairs of points
dist = cdist(df, df, metric='cityblock')

# Display the distances
print(dist)
# Out:
# [[ 0.   2.7  3.7 ...  6.7  7.   9.3]
#  [ 2.7  0.   1.4 ...  8.4  4.7 11. ]
#  [ 3.7  1.4  0.  ...  9.8  4.1 12.4]
#  ...
#  [ 6.7  8.4  9.8 ...  0.  12.5  3.6]
#  [ 7.   4.7  4.1 ... 12.5  0.  14.9]
#  [ 9.3 11.  12.4 ...  3.6 14.9  0. ]]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
# Perform hierarchical clustering using Diana

X= df

Z = linkage(dist, 'ward')

# Obtain cluster labels for a specific distance threshold
distance_threshold = 3
labels = fcluster(Z, distance_threshold, criterion='distance')

# Add the cluster labels to the DataFrame
df['cluster'] = labels

# Print the DataFrame with cluster labels
print(df)

# Plot the dendrogram (optional)
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
dendrogram(Z,orientation='bottom')
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
#     sepal_length  sepal_width  cluster
# 0            5.1          3.5       33
# 1            4.9          3.0       29
# 2            4.7          3.2       28
# 3            4.6          3.1       28
# 4            5.0          3.6       31
# ..           ...          ...      ...
# 95           5.7          3.0       10
# 96           5.7          2.9       10
# 97           6.2          2.9       12
# 98           5.1          2.5       27
# 99           5.7          2.8        7
#
# [100 rows x 3 columns]
# <ipython-input-41-a4eefb9d1770>:6: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'ward')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'single')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - single)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-42-13a65d523682>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'single')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'complete')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - complete)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-43-b04236d03060>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'complete')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'ward')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - ward)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-44-a1745fbe19a2>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'ward')

# %% [markdown]
#  Maximum norm

# %%
# Calculate the Chebyshev distance between all pairs of points
dist = cdist(df, df, metric='chebyshev')

# Display the distances
print(dist)
# Out:
# [[ 0.  4.  5. ... 21.  6. 26.]
#  [ 4.  0.  1. ... 17.  2. 22.]
#  [ 5.  1.  0. ... 16.  1. 21.]
#  ...
#  [21. 17. 16. ...  0. 15.  5.]
#  [ 6.  2.  1. ... 15.  0. 20.]
#  [26. 22. 21. ...  5. 20.  0.]]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
# Perform hierarchical clustering using Diana

X= df

Z = linkage(dist, 'ward')

# Obtain cluster labels for a specific distance threshold
distance_threshold = 3
labels = fcluster(Z, distance_threshold, criterion='distance')

# Add the cluster labels to the DataFrame
df['cluster'] = labels

# Print the DataFrame with cluster labels
print(df)

# Plot the dendrogram (optional)
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
dendrogram(Z,orientation='bottom')
plt.gca()
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
#     sepal_length  sepal_width  cluster
# 0            5.1          3.5       27
# 1            4.9          3.0       29
# 2            4.7          3.2       28
# 3            4.6          3.1       28
# 4            5.0          3.6       25
# ..           ...          ...      ...
# 95           5.7          3.0       10
# 96           5.7          2.9       10
# 97           6.2          2.9       12
# 98           5.1          2.5       31
# 99           5.7          2.8        7
#
# [100 rows x 3 columns]
# <ipython-input-46-830248d3c073>:6: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'ward')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'single')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - single)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-47-13a65d523682>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'single')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'complete')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - complete)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-48-b04236d03060>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'complete')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'ward')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - ward)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-49-a1745fbe19a2>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'ward')

# %% [markdown]
# Mahalanobis distance

# %%
# Calculate the Mahalanobis distance between all pairs of points
VI = np.linalg.inv(df.cov())
dist = cdist(df, df, metric='mahalanobis', VI=VI)

# Display the distances
print(dist)
# Out:
# [[0.         1.23467847 1.21610309 ... 2.00354159 2.93881436 2.71968659]
#  [1.23467847 0.         1.18340688 ... 2.03945416 1.94735891 2.86935506]
#  [1.21610309 1.18340688 0.         ... 2.62379649 3.10873307 2.22342824]
#  ...
#  [2.00354159 2.03945416 2.62379649 ... 0.         2.60552181 2.81505811]
#  [2.93881436 1.94735891 3.10873307 ... 2.60552181 0.         4.40242785]
#  [2.71968659 2.86935506 2.22342824 ... 2.81505811 4.40242785 0.        ]]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
# Perform hierarchical clustering using Diana

X= df

Z = linkage(dist, 'ward')

# Obtain cluster labels for a specific distance threshold
distance_threshold = 3
labels = fcluster(Z, distance_threshold, criterion='distance')

# Add the cluster labels to the DataFrame
df['cluster'] = labels

# Print the DataFrame with cluster labels
print(df)

# Plot the dendrogram (optional)
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
dendrogram(Z,orientation='bottom')
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
#     sepal_length  sepal_width  cluster
# 0            5.1          3.5       21
# 1            4.9          3.0       17
# 2            4.7          3.2       16
# 3            4.6          3.1       16
# 4            5.0          3.6       10
# ..           ...          ...      ...
# 95           5.7          3.0       37
# 96           5.7          2.9       37
# 97           6.2          2.9       27
# 98           5.1          2.5       22
# 99           5.7          2.8       39
#
# [100 rows x 3 columns]
# <ipython-input-51-a4eefb9d1770>:6: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'ward')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'single')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - single)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-52-13a65d523682>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'single')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'complete')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - complete)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-53-b04236d03060>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'complete')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'ward')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - ward)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
# <ipython-input-54-a1745fbe19a2>:11: ClusterWarning: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dist, 'ward')

# %% [markdown]
# Inner Product Space Diatance

# %%
import numpy as np
from scipy.spatial.distance import cdist

def inner_product_metric(u, v):
    """Calculates the inner product distance between two vectors."""
    return np.dot(u, v)

# Calculate the inner product space distance between all pairs of points
dist = cdist(df, df, metric=inner_product_metric)

# Display the distances
print(dist)
# Out:
# [[ 479.26  392.49  371.17 ...  608.77  496.76  857.87]
#  [ 392.49  322.01  304.63 ...  498.08  406.49  699.33]
#  [ 371.17  304.63  288.33 ...  470.42  383.97  659.75]
#  ...
#  [ 608.77  498.08  470.42 ...  775.85  632.87 1096.46]
#  [ 496.76  406.49  383.97 ...  632.87  516.26  894.07]
#  [ 857.87  699.33  659.75 ... 1096.46  894.07 1561.33]]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
# Perform hierarchical clustering using Diana

X= df

Z = linkage(dist, 'ward')

# Obtain cluster labels for a specific distance threshold
distance_threshold = 3
labels = fcluster(Z, distance_threshold, criterion='distance')

# Add the cluster labels to the DataFrame
df['cluster'] = labels

# Print the DataFrame with cluster labels
print(df)

# Plot the dendrogram (optional)
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
dendrogram(Z,orientation='bottom')
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
# Out:
#     sepal_length  sepal_width  cluster
# 0            5.1          3.5       75
# 1            4.9          3.0       50
# 2            4.7          3.2       45
# 3            4.6          3.1       46
# 4            5.0          3.6       34
# ..           ...          ...      ...
# 95           5.7          3.0       21
# 96           5.7          2.9       22
# 97           6.2          2.9       64
# 98           5.1          2.5       66
# 99           5.7          2.8       27
#
# [100 rows x 3 columns]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'single')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - single)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'complete')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - complete)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Perform hierarchical clustering using Agnes with different linkage methods

Z = linkage(dist, 'ward')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(Z)
plt.title(f'Hierarchical Clustering Dendrogram (Agnes - ward)')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# 3. Evaluation technique to use a) Elbow

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Sample data (replace with your own data)
X = df

# Calculate WCSS for different values of K
wcss = []
for i in range(1, 11):
  kmeans = KMeans(n_clusters=i, random_state=42)
  kmeans.fit(X)
  wcss.append(kmeans.inertia_)

# Calculate angles between slopes
angles = []
for i in range(1, len(wcss)-1):
  slope1 = wcss[i] - wcss[i-1]
  slope2 = wcss[i+1] - wcss[i]
  angle = np.arctan((slope2 - slope1) / (1 + slope1 * slope2))
  angles.append(abs(angle))

# Find the elbow point (K value) with the maximum angle
optimal_k = angles.index(max(angles)) + 2  # +2 because we start from K=2

# Plot the Elbow method graph with the optimal K
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# 3. Evaluation technique to use b) Silhoutte score (Histogram)

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Select the columns you want to use for clustering
X = df

# Specify the number of clusters (K) - replace with your desired value
K = 3

# Perform K-means clustering
kmeans = KMeans(n_clusters=K, random_state=42)
cluster_labels = kmeans.fit_predict(X)

# Calculate Silhouette score
silhouette_avg = silhouette_score(X, cluster_labels)
print(f'Average Silhouette score: {silhouette_avg}')

# Calculate Silhouette scores for each sample
sample_silhouette_values = silhouette_samples(X, cluster_labels)

# Create Silhouette plot (histogram)
fig, ax1 = plt.subplots(1, 1)
fig.set_size_inches(18, 7)
ax1.set_xlim([-0.1, 1])
ax1.set_ylim([0, len(X) + (K + 1) * 10])

y_lower = 10
for i in range(K):
    ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]
    ith_cluster_silhouette_values.sort()
    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i
    color = plt.cm.nipy_spectral(float(i) / K)
    ax1.fill_betweenx(np.arange(y_lower, y_upper),
                      0, ith_cluster_silhouette_values,
                      facecolor=color, edgecolor=color, alpha=0.7)
    ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
    y_lower = y_upper + 10

ax1.set_title('Silhouette plot for the various clusters')
ax1.set_xlabel("Silhouette coefficient values")
ax1.set_ylabel("Cluster label")
ax1.axvline(x=silhouette_avg, color="red", linestyle="--")
ax1.set_yticks([])
ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Average Silhouette score: 0.5602017493166277
